# %% [markdown]
# ### Ejemplos IF else y mas álla.
#
# Diseñe un algoritmo que de un conjunto de mensajes acorde a la calificación de una materia:
#
# MENOR QUE 60:  "HECHALE GANAS"
# 60-70 "VAS BIEN"
# 71-80 "EXCELENTE"
# 81-90 "PUROS BARCOS"
# 91-100 "PURA VANIDAD"
# ![image.png](attachment:69721abe-5acb-4169-9284-be68f144f06e.png)

# %%
cc=float(input("Escribe tu calificacion"))

if cc>=0 and cc<60:
    print("HECHALE GANAS VALEDOR")
elif cc>=60 and cc <=70:
    print("VAS BIEN")
elif cc>=71 and cc <=80:
    print("EXCELENTE")
elif cc>=81 and cc <=90:
    print("PURO BARCO")
elif cc>=91 and cc <=100:
    print("PURA VANIDAD")
else:
    print("Fuera de rango")
# Out:
# Escribe tu calificacion 110
# Fuera de rango

# %%
aa=5
bb=9
cc=0

if cc != 0:  # c1
    if aa >6:#c2
        #algo 2
        if aa >0 and aa<= cc: # c3
            pass#algo 3
        else:
            pass# algo 4
else:
        pass# algo 1

# %%
aa,bb,cc=7,9,1
if cc != 0: # c1
    if aa >6:#c2
        print("aa es mayo que 6")
        if aa >0 and aa<= bb: # c3
            print("aa es mayo que cero y menor que 9")
        else:
            print("aa no es mayor que 0  y/o aa no es <= 9")
    else:
        print("aa no es mayor que 6")
else:
    print("cc es cero")
# Out:
# aa es mayo que 6
# aa es mayo que cero y menor que 9
